-- %%
--list catalogs
show catalogs like 'dev*'

-- %%
--list schema& tables
show schemas in dev like '*i*';
show tables in dev.bronze;

-- %%
--if fnot exists clause
create table IF not Exists dev.bronze.emp
(emp_id int,
 name string,
 dept string,
 salary int);

-- %%
insert into dev.bronze.emp
values(1,'John','IT',50000),
(2,'Mary','HR',60000),
(3,'Mike','IT',55000),
(4,'Jane','IT',52000),
(5,'Tom','HR',65000);
select * from dev.bronze.emp;

-- %%
describe history dev.bronze.emp;

-- %%
-- create temp & permentent views
create temporary view emp_temp_view as
select * from dev.bronze.emp where dept='IT';

-- %%
select * from emp_temp_view;

-- %%
-- create temp & permentent views
create or replace view dev.bronze.emp_view as
select * from dev.bronze.emp where dept='IT';

-- %%
CREATE TABLE dev.bronze.emp_ctas AS
select * from dev.bronze.emp;

-- %%
select * from dev.bronze.emp_ctas;

-- %%
describe extended dev.bronze.emp_ctas;

-- %%
describe extended dev.bronze.emp;
