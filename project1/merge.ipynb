-- %%
---emp table
select * from dev.bronze.emp

-- %%
--create table emp_updates
create table if not exists dev.bronze.emp_updates
(emp_id int,
 name string,
 dept string,
 salary int);

-- %%
--insert into emp_updates
insert into dev.bronze.emp_updates (emp_id, name, dept, salary)
values (6, 'John', 'Sales', 50000),
 (7, 'Jane', 'Marketing', 60000),
 (8, 'Bob', 'Engineering',70000)

-- %%
--update into emp_updates
insert into dev.bronze.emp_updates (emp_id, name, dept, salary)
values (1,'John','IT',50000),
(2,'Mary','HR',60000),
(3,'Mike','IT',55000)

-- %%
select * from dev.bronze.emp_updates

-- %%
--merge query
MERGE INTO dev.bronze.emp e
USING dev.bronze.emp_updates s
ON e.emp_id = s.emp_id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *

-- %%
select * from dev.bronze.emp

-- %%
alter table dev.bronze.emp add column is_active string

-- %%
--merge query
MERGE INTO dev.bronze.emp e
USING dev.bronze.emp_updates s
ON e.emp_id = s.emp_id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *
--when not MATCHED by SOURCE THEN /* not recommented as it is hard delete
--DELETE
;

-- %%
--merge query
MERGE INTO dev.bronze.emp e
USING dev.bronze.emp_updates s
ON e.emp_id = s.emp_id
WHEN MATCHED THEN UPDATE SET e.name = s.name, e.dept = s.dept, e.salary = s.salary, e.is_active = 'Y'
WHEN NOT MATCHED THEN INSERT (emp_id, name, dept, salary, is_active) VALUES (s.emp_id, s.name, s.dept, s.salary, 'Y')
when not MATCHED by SOURCE THEN 
UPDATE SET e.is_active = 'N'
;

-- %%
select  * from dev.bronze.emp
